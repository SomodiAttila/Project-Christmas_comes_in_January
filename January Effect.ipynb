# %%
# importing necessarry libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Data preparation

# %%
small_cap = pd.read_excel('MSCI.xls', sheet_name='Small cap')

# %%
small_cap
# Out:
#           DATE  AUSTRALIA    BRAZIL    CANADA    FRANCE    GERMANY    \
# 0   1998-12-01       74.984   104.135   104.526   119.866    117.268
# 1   1999-01-01       80.285    64.627   106.348   113.533    109.428
# 2   1999-02-01       78.309    65.858   101.328   110.744    106.042
# 3   1999-03-01       81.494    90.684   107.037   109.820    104.349
# 4   1999-04-01       87.420    94.651   119.991   118.226    110.276
# ..         ...          ...       ...       ...       ...        ...
# 248 2019-08-01      197.027  1061.063   365.051   487.227    242.646
# 249 2019-09-01      198.382  1075.450   364.052   488.795    244.392
# 250 2019-10-01      199.840  1144.242   362.474   497.099    256.977
# 251 2019-11-01      199.500  1134.678   372.600   502.284    262.816
# 252 2019-12-01      205.579  1334.204   399.587   533.564    279.979
#
#      HONG KONG     INDIA    ITALY    JAPAN    KOREA    NETHERLANDS    \
# ...

# %%
mid_cap = pd.read_excel('MSCI.xls', sheet_name='Mid cap')

# %%
mid_cap
# Out:
#           DATE  AUSTRALIA    BRAZIL    CANADA    FRANCE    GERMANY    \
# 0   1998-12-01      265.623   175.083   202.368   369.403    461.722
# 1   1999-01-01      275.641   117.623   215.644   369.152    455.105
# 2   1999-02-01      277.346   124.057   207.335   345.943    437.512
# 3   1999-03-01      284.946   178.949   224.175   346.170    421.701
# 4   1999-04-01      306.343   209.302   253.794   363.209    425.769
# ..         ...          ...       ...       ...       ...        ...
# 248 2019-08-01      824.925   992.246  1101.634   978.732    792.504
# 249 2019-09-01      835.298  1002.209  1087.023   993.236    808.223
# 250 2019-10-01      862.256  1054.222  1091.554  1040.414    815.533
# 251 2019-11-01      878.536  1031.273  1114.231  1051.696    844.045
# 252 2019-12-01      875.694  1184.973  1149.207  1079.185    878.862
#
#      HONG KONG     INDIA    ITALY     JAPAN    KOREA    NETHERLANDS    \
# ...

# %%
large_cap = pd.read_excel('MSCI.xls', sheet_name='Large cap')

# %%
large_cap
# Out:
#           DATE  AUSTRALIA    BRAZIL    CANADA    FRANCE    GERMANY    \
# 0   1998-12-01      387.806   190.620   325.956   561.925    692.943
# 1   1999-01-01      417.916   124.962   351.099   584.557    703.722
# 2   1999-02-01      404.348   135.749   330.490   546.648    650.871
# 3   1999-03-01      424.362   187.063   340.029   554.192    631.392
# 4   1999-04-01      463.813   209.645   368.756   567.940    667.982
# ..         ...          ...       ...       ...       ...        ...
# 248 2019-08-01      853.581   692.021   911.619   771.749    819.287
# 249 2019-09-01      871.007   712.447   936.233   791.516    840.112
# 250 2019-10-01      882.298   756.590   931.085   818.073    897.908
# 251 2019-11-01      882.034   715.914   953.036   832.735    911.379
# 252 2019-12-01      898.135   790.777   974.065   857.390    925.238
#
#      HONG KONG     INDIA    ITALY     JAPAN     KOREA    NETHERLANDS    \
# ...

# %%
small_cap.dtypes
# Out:
# DATE                datetime64[ns]
# AUSTRALIA                  float64
# BRAZIL                     float64
# CANADA                     float64
# FRANCE                     float64
# GERMANY                    float64
# HONG KONG                  float64
# INDIA                      float64
# ITALY                      float64
# JAPAN                      float64
# KOREA                      float64
# NETHERLANDS                float64
# RUSSIA                     float64
# SPAIN                      float64
# UNITED KINGDOM             float64
# USA                        float64
# dtype: object

# %%
mid_cap.dtypes
# Out:
# DATE                datetime64[ns]
# AUSTRALIA                  float64
# BRAZIL                     float64
# CANADA                     float64
# FRANCE                     float64
# GERMANY                    float64
# HONG KONG                  float64
# INDIA                      float64
# ITALY                      float64
# JAPAN                      float64
# KOREA                      float64
# NETHERLANDS                float64
# RUSSIA                     float64
# SPAIN                      float64
# UNITED KINGDOM             float64
# USA                        float64
# dtype: object

# %%
large_cap.dtypes
# Out:
# DATE                datetime64[ns]
# AUSTRALIA                  float64
# BRAZIL                     float64
# CANADA                     float64
# FRANCE                     float64
# GERMANY                    float64
# HONG KONG                  float64
# INDIA                      float64
# ITALY                      float64
# JAPAN                      float64
# KOREA                      float64
# NETHERLANDS                float64
# RUSSIA                     float64
# SPAIN                      float64
# UNITED KINGDOM             float64
# USA                        float64
# dtype: object

# %%
small_cap.isna().sum()
# Out:
# DATE                0
# AUSTRALIA           0
# BRAZIL              0
# CANADA              0
# FRANCE              0
# GERMANY             0
# HONG KONG           0
# INDIA               0
# ITALY               0
# JAPAN               0
# KOREA               0
# NETHERLANDS         0
# RUSSIA              0
# SPAIN               0
# UNITED KINGDOM      0
# USA                 0
# dtype: int64

# %%
mid_cap.isna().sum()
# Out:
# DATE                0
# AUSTRALIA           0
# BRAZIL              0
# CANADA              0
# FRANCE              0
# GERMANY             0
# HONG KONG           0
# INDIA               0
# ITALY               0
# JAPAN               0
# KOREA               0
# NETHERLANDS         0
# RUSSIA              0
# SPAIN               0
# UNITED KINGDOM      0
# USA                 0
# dtype: int64

# %%
large_cap.isna().sum()
# Out:
# DATE                0
# AUSTRALIA           0
# BRAZIL              0
# CANADA              0
# FRANCE              0
# GERMANY             0
# HONG KONG           0
# INDIA               0
# ITALY               0
# JAPAN               0
# KOREA               0
# NETHERLANDS         0
# RUSSIA              0
# SPAIN               0
# UNITED KINGDOM      0
# USA                 0
# dtype: int64

# %%
fig_1 = plt.figure(figsize=(6,4), dpi=100)
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9])
axes_1.xlabel('Time')
axes_1.ylabel('Index level')
axes_1.set_title('Small cap indices')
plt.plot(small_cap)
